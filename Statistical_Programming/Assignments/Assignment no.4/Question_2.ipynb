# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
Mean=2
Std=2
n=[10,100,1000,10000,1000000]
for i in n:
    values = np.random.normal(Mean, Std, i)
    values=((values-2)/2)*((values-2)/2)
    sns.kdeplot(values)
    plt.figure()
