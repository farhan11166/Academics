# %% [markdown]
# ***DATA COLLECTION ASSIGNEMENT***

# %% [markdown]
# Data collection and visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_style("whitegrid")

fig, axes = plt.subplots(1, 3, figsize=(18, 5))


sns.histplot(df["Age"], bins=10, kde=True, ax=axes[0], color="blue")
axes[0].set_title("Age Distribution")


sns.histplot(df["How old is your smartphone (in years)?"], bins=10, kde=True, ax=axes[1], color="green")
axes[1].set_title("Smartphone Age Distribution")


sns.histplot(df["Price of smartphone"], bins=10, kde=True, ax=axes[2], color="red")
axes[2].set_title("Price Distribution")

plt.tight_layout()
plt.show()
plt.figure(figsize=(10, 5))
sns.countplot(x="Brand of smartphone", data=df, order=df["Brand of smartphone"].value_counts().index, palette="viridis")
plt.xticks(rotation=45)
plt.title("Distribution of Smartphone Brands")
plt.show()


plt.figure(figsize=(12, 6))
sns.boxplot(x="Brand of smartphone", y="Price of smartphone", data=df, palette="coolwarm")
plt.xticks(rotation=45)
plt.title("Smartphone Price by Brand")
plt.show()
# Out:
# <ipython-input-23-66268f4d3eab>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Brand of smartphone", data=df, order=df["Brand of smartphone"].value_counts().index, palette="viridis")
# <ipython-input-23-66268f4d3eab>:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Brand of smartphone", y="Price of smartphone", data=df, palette="coolwarm")

# %% [markdown]
# K means clusttering

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv("cleaned_data.csv")

# Define features for clustering
X = df[["Age", "How old is your smartphone (in years)?", "Price of smartphone"]]

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
kmeans.fit(X_scaled)

# Add cluster labels to dataset
df["Cluster"] = kmeans.labels_

# Visualization
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df["Age"], y=df["Price of smartphone"], hue=df["Cluster"], palette="viridis")
plt.xlabel("Age")
plt.ylabel("Price of Smartphone")
plt.title("K-Means Clustering of Smartphone Data")
plt.show()
